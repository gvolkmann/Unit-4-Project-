# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd


# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name = 'Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_T = properties.T

# %%
properties_T.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# City of London                  84409.1              94900.5
# Barking & Dagenham              53042.2              53700.3
# Barnet                            90258              90107.2
# Bexley                          63997.1              64252.3
#
#                                     7                    8    \
# Unnamed: 0          1995-07-01 00:00:00  1995-08-01 00:00:00
# City of London                   110128               112329
# Barking & Dagenham              52113.1              52232.2
# Barnet                          91441.2              92361.3
# Bexley                          63722.7              64432.6
#
#                                     9    ...                  294  \
# Unnamed: 0          1995-09-01 00:00:00  ...  2019-06-01 00:00:00
# City of London                   104473  ...               761526
# Barking & Dagenham              51471.6  ...               293889
# Barnet                          93273.1  ...               512694
# Bexley                          64509.5  ...               339324
#
#                                     295                  296  \
# Unnamed: 0          2019-07-01 00:00:00  2019-08-01 00:00:00
# City of London                   756407               813770
# Barking & Dagenham               297426               299421
# Barnet                           514668               528577
# Bexley                           338346               337523
#
#                                     297                  298  \
# Unnamed: 0          2019-09-01 00:00:00  2019-10-01 00:00:00
# City of London                   810455               826227
# Barking & Dagenham               304778               304579
# Barnet                           526670               525678
# Bexley                           333340               332920
#
#                                     299                  300  \
# Unnamed: 0          2019-11-01 00:00:00  2019-12-01 00:00:00
# City of London                   776894               737275
# Barking & Dagenham               306390               301283
# Barnet                           522639               519306
# Bexley                           333657               336302
#
#                                     301                  302  \
# Unnamed: 0          2020-01-01 00:00:00  2020-02-01 00:00:00
# City of London                   757377               765416
# Barking & Dagenham               304187               304719
# Barnet                           520115               520966
# Bexley                           334430               334845
#
#                                     303
# Unnamed: 0          2020-03-01 00:00:00
# City of London                   792583
# Barking & Dagenham               327136
# Barnet                           532569
# Bexley                           331679
#
# [5 rows x 304 columns]

# %%
properties_T.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties_T = properties_T.reset_index()

# %%
properties_T.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
#                    294                  295                  296  \
# 0  2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00
# 1               761526               756407               813770
# 2               293889               297426               299421
# 3               512694               514668               528577
# 4               339324               338346               337523
#
#                    297                  298                  299  \
# 0  2019-09-01 00:00:00  2019-10-01 00:00:00  2019-11-01 00:00:00
# 1               810455               826227               776894
# 2               304778               304579               306390
# 3               526670               525678               522639
# 4               333340               332920               333657
#
#                    300                  301                  302  \
# 0  2019-12-01 00:00:00  2020-01-01 00:00:00  2020-02-01 00:00:00
# 1               737275               757377               765416
# 2               301283               304187               304719
# 3               519306               520115               520966
# 4               336302               334430               334845
#
#                    303
# 0  2020-03-01 00:00:00
# 1               792583
# 2               327136
# 3               532569
# 4               331679
#
# [5 rows x 305 columns]

# %%
properties_T.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            294,     295,     296,     297,     298,     299,     300,     301,
#            302,     303],
#       dtype='object', length=305)

# %%
properties_T.iloc[[0]]
# Out:
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    294                  295                  296  \
# 0  2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00
#
#                    297                  298                  299  \
# 0  2019-09-01 00:00:00  2019-10-01 00:00:00  2019-11-01 00:00:00
#
#                    300                  301                  302  \
# 0  2019-12-01 00:00:00  2020-01-01 00:00:00  2020-02-01 00:00:00
#
#                    303
# 0  2020-03-01 00:00:00
#
# [1 rows x 305 columns]

# %%
properties_T.columns = properties_T.iloc[0]

# %%
properties_T.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
# 0  2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00  \
# 0  2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00
# 1               761526               756407               813770
# 2               293889               297426               299421
# 3               512694               514668               528577
# 4               339324               338346               337523
#
# 0  2019-09-01 00:00:00  2019-10-01 00:00:00  2019-11-01 00:00:00  \
# 0  2019-09-01 00:00:00  2019-10-01 00:00:00  2019-11-01 00:00:00
# 1               810455               826227               776894
# 2               304778               304579               306390
# 3               526670               525678               522639
# 4               333340               332920               333657
#
# 0  2019-12-01 00:00:00  2020-01-01 00:00:00  2020-02-01 00:00:00  \
# 0  2019-12-01 00:00:00  2020-01-01 00:00:00  2020-02-01 00:00:00
# 1               737275               757377               765416
# 2               301283               304187               304719
# 3               519306               520115               520966
# 4               336302               334430               334845
#
# 0  2020-03-01 00:00:00
# 0  2020-03-01 00:00:00
# 1               792583
# 2               327136
# 3               532569
# 4               331679
#
# [5 rows x 305 columns]

# %%
properties_T = properties_T.drop(0)

# %%
properties_T.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
# 3             90107.2             91441.2             92361.3  ...
# 4             64252.3             63722.7             64432.6  ...
# 5             74310.5               74127               73547  ...
#
# 0 2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 1              761526              756407              813770
# 2              293889              297426              299421
# 3              512694              514668              528577
# 4              339324              338346              337523
# 5              474821              473849              488784
#
# 0 2019-09-01 00:00:00 2019-10-01 00:00:00 2019-11-01 00:00:00  \
# 1              810455              826227              776894
# 2              304778              304579              306390
# 3              526670              525678              522639
# 4              333340              332920              333657
# 5              501533              494770              432188
#
# 0 2019-12-01 00:00:00 2020-01-01 00:00:00 2020-02-01 00:00:00  \
# 1              737275              757377              765416
# 2              301283              304187              304719
# 3              519306              520115              520966
# 4              336302              334430              334845
# 5              427126              424663              471574
#
# 0 2020-03-01 00:00:00
# 1              792583
# 2              327136
# 3              532569
# 4              331679
# 5              446966
#
# [5 rows x 305 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_T = properties_T.rename(columns = {'Unnamed: 0': 'London_Borough', pd.NaT: 'ID'})

# %%
properties_T.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
# 3             90107.2             91441.2             92361.3  ...
# 4             64252.3             63722.7             64432.6  ...
# 5             74310.5               74127               73547  ...
#
# 0 2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 1              761526              756407              813770
# 2              293889              297426              299421
# 3              512694              514668              528577
# 4              339324              338346              337523
# 5              474821              473849              488784
#
# 0 2019-09-01 00:00:00 2019-10-01 00:00:00 2019-11-01 00:00:00  \
# 1              810455              826227              776894
# 2              304778              304579              306390
# 3              526670              525678              522639
# 4              333340              332920              333657
# 5              501533              494770              432188
#
# 0 2019-12-01 00:00:00 2020-01-01 00:00:00 2020-02-01 00:00:00  \
# 1              737275              757377              765416
# 2              301283              304187              304719
# 3              519306              520115              520966
# 4              336302              334430              334845
# 5              427126              424663              471574
#
# 0 2020-03-01 00:00:00
# 1              792583
# 2              327136
# 3              532569
# 4              331679
# 5              446966
#
# [5 rows x 305 columns]

# %%
properties_T.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2019-06-01 00:00:00, 2019-07-01 00:00:00, 2019-08-01 00:00:00,
#        2019-09-01 00:00:00, 2019-10-01 00:00:00, 2019-11-01 00:00:00,
#        2019-12-01 00:00:00, 2020-01-01 00:00:00, 2020-02-01 00:00:00,
#        2020-03-01 00:00:00],
#       dtype='object', name=0, length=305)

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
clean_properties = pd.melt(properties_T, id_vars= ['London_Borough', 'ID'])

# %%
clean_properties = clean_properties.rename(columns = {0: 'Month', 'value':'Average_price'})

# %%
clean_properties.head()
# Out:
#        London_Borough         ID      Month Average_price
# 0      City of London  E09000001 1995-01-01         91449
# 1  Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2              Barnet  E09000003 1995-01-01       93284.5
# 3              Bexley  E09000004 1995-01-01       64958.1
# 4               Brent  E09000005 1995-01-01       71306.6

# %%
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# dtype: object

# %%
clean_properties.count()
# Out:
# London_Borough    14544
# ID                13635
# Month             14544
# Average_price     13635
# dtype: int64

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
clean_properties['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
clean_properties[clean_properties['London_Borough'] == 'Unnamed: 34'].head()
# Out:
#     London_Borough   ID      Month Average_price
# 33     Unnamed: 34  NaN 1995-01-01           NaN
# 81     Unnamed: 34  NaN 1995-02-01           NaN
# 129    Unnamed: 34  NaN 1995-03-01           NaN
# 177    Unnamed: 34  NaN 1995-04-01           NaN
# 225    Unnamed: 34  NaN 1995-05-01           NaN

# %%
clean_properties[clean_properties['ID'].isna()]
# Out:
#       London_Borough   ID      Month Average_price
# 33       Unnamed: 34  NaN 1995-01-01           NaN
# 36       Unnamed: 37  NaN 1995-01-01           NaN
# 46       Unnamed: 47  NaN 1995-01-01           NaN
# 81       Unnamed: 34  NaN 1995-02-01           NaN
# 84       Unnamed: 37  NaN 1995-02-01           NaN
# ...              ...  ...        ...           ...
# 14484    Unnamed: 37  NaN 2020-02-01           NaN
# 14494    Unnamed: 47  NaN 2020-02-01           NaN
# 14529    Unnamed: 34  NaN 2020-03-01           NaN
# 14532    Unnamed: 37  NaN 2020-03-01           NaN
# 14542    Unnamed: 47  NaN 2020-03-01           NaN
#
# [909 rows x 4 columns]

# %%
NaNFreeDF1 = clean_properties[clean_properties['Average_price'].notna()]

# %%
NaNFreeDF1.head(48)
# Out:
#           London_Borough         ID      Month Average_price
# 0         City of London  E09000001 1995-01-01         91449
# 1     Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2                 Barnet  E09000003 1995-01-01       93284.5
# 3                 Bexley  E09000004 1995-01-01       64958.1
# 4                  Brent  E09000005 1995-01-01       71306.6
# 5                Bromley  E09000006 1995-01-01       81671.5
# 6                 Camden  E09000007 1995-01-01        120933
# 7                Croydon  E09000008 1995-01-01       69158.2
# 8                 Ealing  E09000009 1995-01-01       79885.9
# 9                Enfield  E09000010 1995-01-01       72514.7
# 10             Greenwich  E09000011 1995-01-01       62300.1
# 11               Hackney  E09000012 1995-01-01       61296.5
# 12  Hammersmith & Fulham  E09000013 1995-01-01        124903
# 13              Haringey  E09000014 1995-01-01       76287.6
# 14                Harrow  E09000015 1995-01-01       84769.5
# 15              Havering  E09000016 1995-01-01       68000.1
# 16            Hillingdon  E09000017 1995-01-01       73834.8
# 17              Hounslow  E09000018 1995-01-01       72231.7
# 18             Islington  E09000019 1995-01-01       92516.5
# 19  Kensington & Chelsea  E09000020 1995-01-01        182695
# 20  Kingston upon Thames  E09000021 1995-01-01       80875.8
# 21               Lambeth  E09000022 1995-01-01         67771
# 22              Lewisham  E09000023 1995-01-01       60491.3
# 23                Merton  E09000024 1995-01-01       82070.6
# 24                Newham  E09000025 1995-01-01       53539.3
# 25             Redbridge  E09000026 1995-01-01       72189.6
# 26  Richmond upon Thames  E09000027 1995-01-01        109326
# 27             Southwark  E09000028 1995-01-01       67885.2
# 28                Sutton  E09000029 1995-01-01         71537
# 29         Tower Hamlets  E09000030 1995-01-01       59865.2
# 30        Waltham Forest  E09000031 1995-01-01       61319.4
# 31            Wandsworth  E09000032 1995-01-01         88559
# 32           Westminster  E09000033 1995-01-01        133025
# 34          Inner London  E13000001 1995-01-01         78252
# 35          Outer London  E13000002 1995-01-01       72958.8
# 37            NORTH EAST  E12000001 1995-01-01       42076.4
# 38            NORTH WEST  E12000002 1995-01-01       43958.5
# 39    YORKS & THE HUMBER  E12000003 1995-01-01       44803.4
# 40         EAST MIDLANDS  E12000004 1995-01-01       45544.5
# 41         WEST MIDLANDS  E12000005 1995-01-01       48527.5
# 42       EAST OF ENGLAND  E12000006 1995-01-01       56701.6
# 43                LONDON  E12000007 1995-01-01       74435.8
# 44            SOUTH EAST  E12000008 1995-01-01       64018.9
# 45            SOUTH WEST  E12000009 1995-01-01       54705.2
# 47               England  E92000001 1995-01-01       53202.8
# 48        City of London  E09000001 1995-02-01       82202.8
# 49    Barking & Dagenham  E09000002 1995-02-01       51085.8
# 50                Barnet  E09000003 1995-02-01       93190.2

# %%
NaNFreeDF1.count()
# Out:
# London_Borough    13635
# ID                13635
# Month             13635
# Average_price     13635
# dtype: int64

# %%
NaNFreeDF2 = clean_properties.dropna()

# %%
NaNFreeDF2.head(48)
# Out:
#           London_Borough         ID      Month Average_price
# 0         City of London  E09000001 1995-01-01         91449
# 1     Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2                 Barnet  E09000003 1995-01-01       93284.5
# 3                 Bexley  E09000004 1995-01-01       64958.1
# 4                  Brent  E09000005 1995-01-01       71306.6
# 5                Bromley  E09000006 1995-01-01       81671.5
# 6                 Camden  E09000007 1995-01-01        120933
# 7                Croydon  E09000008 1995-01-01       69158.2
# 8                 Ealing  E09000009 1995-01-01       79885.9
# 9                Enfield  E09000010 1995-01-01       72514.7
# 10             Greenwich  E09000011 1995-01-01       62300.1
# 11               Hackney  E09000012 1995-01-01       61296.5
# 12  Hammersmith & Fulham  E09000013 1995-01-01        124903
# 13              Haringey  E09000014 1995-01-01       76287.6
# 14                Harrow  E09000015 1995-01-01       84769.5
# 15              Havering  E09000016 1995-01-01       68000.1
# 16            Hillingdon  E09000017 1995-01-01       73834.8
# 17              Hounslow  E09000018 1995-01-01       72231.7
# 18             Islington  E09000019 1995-01-01       92516.5
# 19  Kensington & Chelsea  E09000020 1995-01-01        182695
# 20  Kingston upon Thames  E09000021 1995-01-01       80875.8
# 21               Lambeth  E09000022 1995-01-01         67771
# 22              Lewisham  E09000023 1995-01-01       60491.3
# 23                Merton  E09000024 1995-01-01       82070.6
# 24                Newham  E09000025 1995-01-01       53539.3
# 25             Redbridge  E09000026 1995-01-01       72189.6
# 26  Richmond upon Thames  E09000027 1995-01-01        109326
# 27             Southwark  E09000028 1995-01-01       67885.2
# 28                Sutton  E09000029 1995-01-01         71537
# 29         Tower Hamlets  E09000030 1995-01-01       59865.2
# 30        Waltham Forest  E09000031 1995-01-01       61319.4
# 31            Wandsworth  E09000032 1995-01-01         88559
# 32           Westminster  E09000033 1995-01-01        133025
# 34          Inner London  E13000001 1995-01-01         78252
# 35          Outer London  E13000002 1995-01-01       72958.8
# 37            NORTH EAST  E12000001 1995-01-01       42076.4
# 38            NORTH WEST  E12000002 1995-01-01       43958.5
# 39    YORKS & THE HUMBER  E12000003 1995-01-01       44803.4
# 40         EAST MIDLANDS  E12000004 1995-01-01       45544.5
# 41         WEST MIDLANDS  E12000005 1995-01-01       48527.5
# 42       EAST OF ENGLAND  E12000006 1995-01-01       56701.6
# 43                LONDON  E12000007 1995-01-01       74435.8
# 44            SOUTH EAST  E12000008 1995-01-01       64018.9
# 45            SOUTH WEST  E12000009 1995-01-01       54705.2
# 47               England  E92000001 1995-01-01       53202.8
# 48        City of London  E09000001 1995-02-01       82202.8
# 49    Barking & Dagenham  E09000002 1995-02-01       51085.8
# 50                Barnet  E09000003 1995-02-01       93190.2

# %%
NaNFreeDF2.count()
# Out:
# London_Borough    13635
# ID                13635
# Month             13635
# Average_price     13635
# dtype: int64

# %%
NaNFreeDF2['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
print(clean_properties.shape)
print(NaNFreeDF1.shape)
print(NaNFreeDF2.shape)
# Out:
# (14544, 4)
# (13635, 4)
# (13635, 4)

# %%
nonBoroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
NaNFreeDF2[NaNFreeDF2.London_Borough.isin(nonBoroughs)]
# Out:
#            London_Borough         ID      Month Average_price
# 34           Inner London  E13000001 1995-01-01         78252
# 35           Outer London  E13000002 1995-01-01       72958.8
# 37             NORTH EAST  E12000001 1995-01-01       42076.4
# 38             NORTH WEST  E12000002 1995-01-01       43958.5
# 39     YORKS & THE HUMBER  E12000003 1995-01-01       44803.4
# ...                   ...        ...        ...           ...
# 14538     EAST OF ENGLAND  E12000006 2020-03-01        291254
# 14539              LONDON  E12000007 2020-03-01        485794
# 14540          SOUTH EAST  E12000008 2020-03-01        323353
# 14541          SOUTH WEST  E12000009 2020-03-01        263360
# 14543             England  E92000001 2020-03-01        248271
#
# [3636 rows x 4 columns]

# %%
NaNFreeDF2[~NaNFreeDF2.London_Borough.isin(nonBoroughs)]
# Out:
#            London_Borough         ID      Month Average_price
# 0          City of London  E09000001 1995-01-01         91449
# 1      Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2                  Barnet  E09000003 1995-01-01       93284.5
# 3                  Bexley  E09000004 1995-01-01       64958.1
# 4                   Brent  E09000005 1995-01-01       71306.6
# ...                   ...        ...        ...           ...
# 14524              Sutton  E09000029 2020-03-01        377458
# 14525       Tower Hamlets  E09000030 2020-03-01        472662
# 14526      Waltham Forest  E09000031 2020-03-01        437153
# 14527          Wandsworth  E09000032 2020-03-01        624858
# 14528         Westminster  E09000033 2020-03-01   1.08501e+06
#
# [9999 rows x 4 columns]

# %%
NaNFreeDF2 = NaNFreeDF2[~NaNFreeDF2.London_Borough.isin(nonBoroughs)]

# %%
NaNFreeDF2.head()
# Out:
#        London_Borough         ID      Month Average_price
# 0      City of London  E09000001 1995-01-01         91449
# 1  Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2              Barnet  E09000003 1995-01-01       93284.5
# 3              Bexley  E09000004 1995-01-01       64958.1
# 4               Brent  E09000005 1995-01-01       71306.6

# %%
df = NaNFreeDF2

# %%
df.head()
# Out:
#        London_Borough         ID      Month Average_price
# 0      City of London  E09000001 1995-01-01         91449
# 1  Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2              Barnet  E09000003 1995-01-01       93284.5
# 3              Bexley  E09000004 1995-01-01       64958.1
# 4               Brent  E09000005 1995-01-01       71306.6

# %%
df.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
islington_prices = df[df['London_Borough'] == 'Islington']

# %%
ax = islington_prices.plot(kind ='line', x = 'Month', y = 'Average_price')

# %%
ax.set_ylabel('Price')
# Out:
# Text(3.200000000000003, 0.5, 'Price')

# %%
df['Year'] = df['Month'].apply(lambda t: t.year)

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df.tail()
# Out:
#        London_Borough         ID      Month Average_price  Year
# 14524          Sutton  E09000029 2020-03-01        377458  2020
# 14525   Tower Hamlets  E09000030 2020-03-01        472662  2020
# 14526  Waltham Forest  E09000031 2020-03-01        437153  2020
# 14527      Wandsworth  E09000032 2020-03-01        624858  2020
# 14528     Westminster  E09000033 2020-03-01   1.08501e+06  2020

# %%
df.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# Year                       int64
# dtype: object

# %%
dfg = df.groupby(['London_Borough','Average_price']).mean()

# %%
dfg.sample(10)
# Out:
#                                   Year
# London_Borough     Average_price
# Waltham Forest     225087.25640   2007
# Haringey           555530.58119   2018
# Wandsworth         248156.41870   2003
# Islington          303348.08870   2005
# Wandsworth         282206.89100   2005
# Sutton             232560.59170   2010
# Croydon            91178.99822    1999
# Barking & Dagenham 89194.04942    2001
# Westminster        654620.46860   2012
# Lambeth            72935.26520    1996

# %%
dfg = dfg.reset_index()

# %%
dfg.head()
# Out:
#        London_Borough  Average_price  Year
# 0  Barking & Dagenham    50460.22660  1995
# 1  Barking & Dagenham    50621.10709  1996
# 2  Barking & Dagenham    50761.40069  1996
# 3  Barking & Dagenham    50828.11236  1996
# 4  Barking & Dagenham    50848.67787  1995

# %%
dfg.count()
# Out:
# London_Borough    9999
# Average_price     9999
# Year              9999
# dtype: int64

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(d):
    y1998 = d['Average_price'][d['Year']==1998]
    y2018 = d['Average_price'][d['Year']==2018]
    ratio = [y2018/y1998]
    return ratio

# %%
create_price_ratio(dfg[dfg['London_Borough']=='Barking & Dagenham'])
# Out:
# [34    NaN
#  35    NaN
#  37    NaN
#  39    NaN
#  40    NaN
#  41    NaN
#  42    NaN
#  43    NaN
#  44    NaN
#  45    NaN
#  46    NaN
#  47    NaN
#  270   NaN
#  272   NaN
#  273   NaN
#  274   NaN
#  277   NaN
#  284   NaN
#  285   NaN
#  288   NaN
#  289   NaN
#  293   NaN
#  294   NaN
#  296   NaN
#  Name: Average_price, dtype: float64]

# %%
final = {}

# %%
for b in dfg['London_Borough'].unique(): 
    borough = dfg[dfg['London_Borough'] == b]
    final[b] = create_price_ratio(borough)
print(final)
# Out:
# {'Barking & Dagenham': [34    NaN
# 35    NaN
# 37    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 270   NaN
# 272   NaN
# 273   NaN
# 274   NaN
# 277   NaN
# 284   NaN
# 285   NaN
# 288   NaN
# 289   NaN
# 293   NaN
# 294   NaN
# 296   NaN
# Name: Average_price, dtype: float64], 'Barnet': [339   NaN
# 340   NaN
# 341   NaN
# 342   NaN
# 343   NaN
# 344   NaN
# 345   NaN
# 346   NaN
# 347   NaN
# 348   NaN
# 349   NaN
# 350   NaN
# 569   NaN
# 571   NaN
# 580   NaN
# 581   NaN
# 585   NaN
# 587   NaN
# 589   NaN
# 591   NaN
# 592   NaN
# 594   NaN
# 596   NaN
# 600   NaN
# Name: Average_price, dtype: float64], 'Bexley': [642   NaN
# 643   NaN
# 644   NaN
# 645   NaN
# 646   NaN
# 647   NaN
# 648   NaN
# 649   NaN
# 650   NaN
# 651   NaN
# 654   NaN
# 656   NaN
# 884   NaN
# 890   NaN
# 895   NaN
# 898   NaN
# 899   NaN
# 900   NaN
# 901   NaN
# 903   NaN
# 905   NaN
# 906   NaN
# 907   NaN
# 908   NaN
# Name: Average_price, dtype: float64], 'Brent': [944    NaN
# 946    NaN
# 947    NaN
# 948    NaN
# 949    NaN
# 950    NaN
# 951    NaN
# 952    NaN
# 953    NaN
# 954    NaN
# 955    NaN
# 956    NaN
# 1173   NaN
# 1175   NaN
# 1177   NaN
# 1180   NaN
# 1184   NaN
# 1196   NaN
# 1197   NaN
# 1198   NaN
# 1200   NaN
# 1209   NaN
# 1210   NaN
# 1211   NaN
# Name: Average_price, dtype: float64], 'Bromley': [1248   NaN
# 1249   NaN
# 1250   NaN
# 1251   NaN
# 1252   NaN
# 1253   NaN
# 1254   NaN
# 1255   NaN
# 1257   NaN
# 1260   NaN
# 1261   NaN
# 1262   NaN
# 1486   NaN
# 1487   NaN
# 1495   NaN
# 1496   NaN
# 1498   NaN
# 1501   NaN
# 1506   NaN
# 1510   NaN
# 1511   NaN
# 1512   NaN
# 1513   NaN
# 1514   NaN
# Name: Average_price, dtype: float64], 'Camden': [1549   NaN
# 1550   NaN
# 1551   NaN
# 1554   NaN
# 1555   NaN
# 1557   NaN
# 1558   NaN
# 1559   NaN
# 1560   NaN
# 1562   NaN
# 1563   NaN
# 1564   NaN
# 1771   NaN
# 1773   NaN
# 1780   NaN
# 1786   NaN
# 1793   NaN
# 1794   NaN
# 1801   NaN
# 1802   NaN
# 1805   NaN
# 1811   NaN
# 1812   NaN
# 1815   NaN
# Name: Average_price, dtype: float64], 'City of London': [1851   NaN
# 1855   NaN
# 1856   NaN
# 1857   NaN
# 1858   NaN
# 1859   NaN
# 1861   NaN
# 1862   NaN
# 1863   NaN
# 1864   NaN
# 1866   NaN
# 1867   NaN
# 2056   NaN
# 2060   NaN
# 2072   NaN
# 2084   NaN
# 2086   NaN
# 2087   NaN
# 2092   NaN
# 2093   NaN
# 2094   NaN
# 2095   NaN
# 2097   NaN
# 2099   NaN
# Name: Average_price, dtype: float64], 'Croydon': [2157   NaN
# 2158   NaN
# 2159   NaN
# 2160   NaN
# 2161   NaN
# 2162   NaN
# 2163   NaN
# 2164   NaN
# 2165   NaN
# 2167   NaN
# 2169   NaN
# 2171   NaN
# 2387   NaN
# 2394   NaN
# 2399   NaN
# 2400   NaN
# 2407   NaN
# 2408   NaN
# 2409   NaN
# 2411   NaN
# 2413   NaN
# 2414   NaN
# 2416   NaN
# 2417   NaN
# Name: Average_price, dtype: float64], 'Ealing': [2460   NaN
# 2461   NaN
# 2462   NaN
# 2463   NaN
# 2464   NaN
# 2465   NaN
# 2466   NaN
# 2469   NaN
# 2470   NaN
# 2471   NaN
# 2472   NaN
# 2473   NaN
# 2686   NaN
# 2688   NaN
# 2697   NaN
# 2698   NaN
# 2704   NaN
# 2707   NaN
# 2708   NaN
# 2709   NaN
# 2712   NaN
# 2716   NaN
# 2717   NaN
# 2719   NaN
# Name: Average_price, dtype: float64], 'Enfield': [2763   NaN
# 2764   NaN
# 2765   NaN
# 2766   NaN
# 2767   NaN
# 2768   NaN
# 2769   NaN
# 2770   NaN
# 2772   NaN
# 2773   NaN
# 2774   NaN
# 2776   NaN
# 3003   NaN
# 3005   NaN
# 3006   NaN
# 3007   NaN
# 3011   NaN
# 3012   NaN
# 3014   NaN
# 3016   NaN
# 3017   NaN
# 3018   NaN
# 3019   NaN
# 3020   NaN
# Name: Average_price, dtype: float64], 'Greenwich': [3066   NaN
# 3067   NaN
# 3068   NaN
# 3069   NaN
# 3070   NaN
# 3071   NaN
# 3072   NaN
# 3073   NaN
# 3074   NaN
# 3075   NaN
# 3076   NaN
# 3078   NaN
# 3299   NaN
# 3305   NaN
# 3306   NaN
# 3307   NaN
# 3308   NaN
# 3309   NaN
# 3310   NaN
# 3312   NaN
# 3313   NaN
# 3314   NaN
# 3316   NaN
# 3319   NaN
# Name: Average_price, dtype: float64], 'Hackney': [3368   NaN
# 3370   NaN
# 3371   NaN
# 3372   NaN
# 3373   NaN
# 3374   NaN
# 3375   NaN
# 3376   NaN
# 3377   NaN
# 3378   NaN
# 3379   NaN
# 3380   NaN
# 3592   NaN
# 3595   NaN
# 3598   NaN
# 3600   NaN
# 3601   NaN
# 3602   NaN
# 3603   NaN
# 3608   NaN
# 3611   NaN
# 3612   NaN
# 3614   NaN
# 3615   NaN
# Name: Average_price, dtype: float64], 'Hammersmith & Fulham': [3672   NaN
# 3673   NaN
# 3674   NaN
# 3675   NaN
# 3676   NaN
# 3677   NaN
# 3678   NaN
# 3679   NaN
# 3680   NaN
# 3681   NaN
# 3685   NaN
# 3687   NaN
# 3869   NaN
# 3870   NaN
# 3871   NaN
# 3872   NaN
# 3884   NaN
# 3886   NaN
# 3888   NaN
# 3891   NaN
# 3893   NaN
# 3897   NaN
# 3899   NaN
# 3900   NaN
# Name: Average_price, dtype: float64], 'Haringey': [3973   NaN
# 3975   NaN
# 3977   NaN
# 3978   NaN
# 3979   NaN
# 3981   NaN
# 3983   NaN
# 3984   NaN
# 3986   NaN
# 3987   NaN
# 3988   NaN
# 3990   NaN
# 4209   NaN
# 4211   NaN
# 4214   NaN
# 4215   NaN
# 4217   NaN
# 4218   NaN
# 4221   NaN
# 4226   NaN
# 4227   NaN
# 4228   NaN
# 4230   NaN
# 4234   NaN
# Name: Average_price, dtype: float64], 'Harrow': [4278   NaN
# 4279   NaN
# 4280   NaN
# 4281   NaN
# 4282   NaN
# 4283   NaN
# 4284   NaN
# 4285   NaN
# 4286   NaN
# 4287   NaN
# 4288   NaN
# 4291   NaN
# 4517   NaN
# 4521   NaN
# 4522   NaN
# 4523   NaN
# 4525   NaN
# 4526   NaN
# 4527   NaN
# 4528   NaN
# 4530   NaN
# 4536   NaN
# 4538   NaN
# 4540   NaN
# Name: Average_price, dtype: float64], 'Havering': [4581   NaN
# 4582   NaN
# 4583   NaN
# 4584   NaN
# 4585   NaN
# 4586   NaN
# 4587   NaN
# 4588   NaN
# 4589   NaN
# 4590   NaN
# 4591   NaN
# 4593   NaN
# 4822   NaN
# 4825   NaN
# 4826   NaN
# 4838   NaN
# 4840   NaN
# 4841   NaN
# 4842   NaN
# 4843   NaN
# 4844   NaN
# 4845   NaN
# 4846   NaN
# 4847   NaN
# Name: Average_price, dtype: float64], 'Hillingdon': [4883   NaN
# 4885   NaN
# 4886   NaN
# 4887   NaN
# 4888   NaN
# 4889   NaN
# 4890   NaN
# 4891   NaN
# 4892   NaN
# 4893   NaN
# 4894   NaN
# 4896   NaN
# 5114   NaN
# 5117   NaN
# 5119   NaN
# 5120   NaN
# 5126   NaN
# 5127   NaN
# 5133   NaN
# 5134   NaN
# 5136   NaN
# 5143   NaN
# 5145   NaN
# 5147   NaN
# Name: Average_price, dtype: float64], 'Hounslow': [5187   NaN
# 5188   NaN
# 5189   NaN
# 5190   NaN
# 5191   NaN
# 5192   NaN
# 5193   NaN
# 5194   NaN
# 5196   NaN
# 5198   NaN
# 5200   NaN
# 5201   NaN
# 5409   NaN
# 5410   NaN
# 5414   NaN
# 5416   NaN
# 5419   NaN
# 5425   NaN
# 5434   NaN
# 5436   NaN
# 5437   NaN
# 5438   NaN
# 5441   NaN
# 5443   NaN
# Name: Average_price, dtype: float64], 'Islington': [5490   NaN
# 5491   NaN
# 5492   NaN
# 5493   NaN
# 5494   NaN
# 5495   NaN
# 5497   NaN
# 5498   NaN
# 5500   NaN
# 5501   NaN
# 5503   NaN
# 5504   NaN
# 5698   NaN
# 5710   NaN
# 5713   NaN
# 5714   NaN
# 5731   NaN
# 5736   NaN
# 5738   NaN
# 5739   NaN
# 5742   NaN
# 5748   NaN
# 5751   NaN
# 5756   NaN
# Name: Average_price, dtype: float64], 'Kensington & Chelsea': [5789   NaN
# 5793   NaN
# 5794   NaN
# 5796   NaN
# 5797   NaN
# 5798   NaN
# 5799   NaN
# 5800   NaN
# 5801   NaN
# 5802   NaN
# 5803   NaN
# 5804   NaN
# 6021   NaN
# 6026   NaN
# 6032   NaN
# 6035   NaN
# 6041   NaN
# 6043   NaN
# 6046   NaN
# 6049   NaN
# 6051   NaN
# 6053   NaN
# 6058   NaN
# 6059   NaN
# Name: Average_price, dtype: float64], 'Kingston upon Thames': [6095   NaN
# 6096   NaN
# 6098   NaN
# 6099   NaN
# 6100   NaN
# 6101   NaN
# 6103   NaN
# 6106   NaN
# 6107   NaN
# 6108   NaN
# 6110   NaN
# 6111   NaN
# 6326   NaN
# 6334   NaN
# 6341   NaN
# 6342   NaN
# 6343   NaN
# 6346   NaN
# 6347   NaN
# 6350   NaN
# 6355   NaN
# 6358   NaN
# 6361   NaN
# 6362   NaN
# Name: Average_price, dtype: float64], 'Lambeth': [6399   NaN
# 6400   NaN
# 6401   NaN
# 6402   NaN
# 6403   NaN
# 6404   NaN
# 6406   NaN
# 6408   NaN
# 6409   NaN
# 6411   NaN
# 6412   NaN
# 6413   NaN
# 6615   NaN
# 6622   NaN
# 6624   NaN
# 6633   NaN
# 6635   NaN
# 6637   NaN
# 6638   NaN
# 6640   NaN
# 6642   NaN
# 6645   NaN
# 6648   NaN
# 6657   NaN
# Name: Average_price, dtype: float64], 'Lewisham': [6702   NaN
# 6703   NaN
# 6704   NaN
# 6705   NaN
# 6706   NaN
# 6707   NaN
# 6708   NaN
# 6709   NaN
# 6710   NaN
# 6712   NaN
# 6713   NaN
# 6714   NaN
# 6935   NaN
# 6937   NaN
# 6940   NaN
# 6943   NaN
# 6945   NaN
# 6946   NaN
# 6947   NaN
# 6954   NaN
# 6956   NaN
# 6960   NaN
# 6961   NaN
# 6964   NaN
# Name: Average_price, dtype: float64], 'Merton': [7005   NaN
# 7006   NaN
# 7007   NaN
# 7008   NaN
# 7009   NaN
# 7010   NaN
# 7011   NaN
# 7012   NaN
# 7014   NaN
# 7016   NaN
# 7017   NaN
# 7018   NaN
# 7227   NaN
# 7228   NaN
# 7231   NaN
# 7234   NaN
# 7238   NaN
# 7257   NaN
# 7261   NaN
# 7262   NaN
# 7264   NaN
# 7267   NaN
# 7269   NaN
# 7270   NaN
# Name: Average_price, dtype: float64], 'Newham': [7308   NaN
# 7309   NaN
# 7310   NaN
# 7311   NaN
# 7312   NaN
# 7313   NaN
# 7314   NaN
# 7315   NaN
# 7316   NaN
# 7317   NaN
# 7320   NaN
# 7322   NaN
# 7528   NaN
# 7530   NaN
# 7533   NaN
# 7535   NaN
# 7538   NaN
# 7545   NaN
# 7550   NaN
# 7554   NaN
# 7561   NaN
# 7562   NaN
# 7563   NaN
# 7568   NaN
# Name: Average_price, dtype: float64], 'Redbridge': [7611   NaN
# 7612   NaN
# 7613   NaN
# 7614   NaN
# 7615   NaN
# 7616   NaN
# 7617   NaN
# 7618   NaN
# 7619   NaN
# 7620   NaN
# 7621   NaN
# 7623   NaN
# 7853   NaN
# 7855   NaN
# 7858   NaN
# 7865   NaN
# 7868   NaN
# 7869   NaN
# 7871   NaN
# 7872   NaN
# 7874   NaN
# 7875   NaN
# 7876   NaN
# 7877   NaN
# Name: Average_price, dtype: float64], 'Richmond upon Thames': [7912   NaN
# 7914   NaN
# 7915   NaN
# 7917   NaN
# 7918   NaN
# 7919   NaN
# 7920   NaN
# 7921   NaN
# 7925   NaN
# 7929   NaN
# 7930   NaN
# 7932   NaN
# 8127   NaN
# 8131   NaN
# 8132   NaN
# 8140   NaN
# 8144   NaN
# 8145   NaN
# 8148   NaN
# 8160   NaN
# 8163   NaN
# 8166   NaN
# 8171   NaN
# 8179   NaN
# Name: Average_price, dtype: float64], 'Southwark': [8213   NaN
# 8216   NaN
# 8218   NaN
# 8220   NaN
# 8221   NaN
# 8222   NaN
# 8223   NaN
# 8224   NaN
# 8225   NaN
# 8226   NaN
# 8227   NaN
# 8228   NaN
# 8438   NaN
# 8440   NaN
# 8445   NaN
# 8447   NaN
# 8451   NaN
# 8452   NaN
# 8453   NaN
# 8458   NaN
# 8461   NaN
# 8470   NaN
# 8474   NaN
# 8476   NaN
# Name: Average_price, dtype: float64], 'Sutton': [8520   NaN
# 8521   NaN
# 8522   NaN
# 8523   NaN
# 8524   NaN
# 8525   NaN
# 8526   NaN
# 8527   NaN
# 8528   NaN
# 8529   NaN
# 8533   NaN
# 8535   NaN
# 8752   NaN
# 8765   NaN
# 8766   NaN
# 8767   NaN
# 8768   NaN
# 8773   NaN
# 8776   NaN
# 8778   NaN
# 8781   NaN
# 8782   NaN
# 8785   NaN
# 8786   NaN
# Name: Average_price, dtype: float64], 'Tower Hamlets': [8823   NaN
# 8824   NaN
# 8825   NaN
# 8826   NaN
# 8827   NaN
# 8828   NaN
# 8829   NaN
# 8830   NaN
# 8831   NaN
# 8832   NaN
# 8833   NaN
# 8836   NaN
# 9044   NaN
# 9045   NaN
# 9046   NaN
# 9049   NaN
# 9051   NaN
# 9054   NaN
# 9056   NaN
# 9058   NaN
# 9060   NaN
# 9068   NaN
# 9069   NaN
# 9078   NaN
# Name: Average_price, dtype: float64], 'Waltham Forest': [9126   NaN
# 9127   NaN
# 9128   NaN
# 9129   NaN
# 9130   NaN
# 9131   NaN
# 9132   NaN
# 9133   NaN
# 9134   NaN
# 9135   NaN
# 9136   NaN
# 9137   NaN
# 9359   NaN
# 9362   NaN
# 9369   NaN
# 9378   NaN
# 9379   NaN
# 9383   NaN
# 9384   NaN
# 9388   NaN
# 9389   NaN
# 9390   NaN
# 9391   NaN
# 9392   NaN
# Name: Average_price, dtype: float64], 'Wandsworth': [9429   NaN
# 9430   NaN
# 9431   NaN
# 9433   NaN
# 9434   NaN
# 9435   NaN
# 9436   NaN
# 9438   NaN
# 9440   NaN
# 9441   NaN
# 9442   NaN
# 9443   NaN
# 9648   NaN
# 9651   NaN
# 9652   NaN
# 9655   NaN
# 9658   NaN
# 9659   NaN
# 9660   NaN
# 9663   NaN
# 9664   NaN
# 9665   NaN
# 9668   NaN
# 9676   NaN
# Name: Average_price, dtype: float64], 'Westminster': [9732   NaN
# 9733   NaN
# 9734   NaN
# 9736   NaN
# 9737   NaN
# 9738   NaN
# 9739   NaN
# 9740   NaN
# 9741   NaN
# 9742   NaN
# 9743   NaN
# 9744   NaN
# 9950   NaN
# 9953   NaN
# 9955   NaN
# 9962   NaN
# 9963   NaN
# 9970   NaN
# 9976   NaN
# 9979   NaN
# 9981   NaN
# 9989   NaN
# 9997   NaN
# 9998   NaN
# Name: Average_price, dtype: float64]}

# %%
df_ratios = pd.DataFrame(final)

# %%
df_ratios.head()
# Out:
#                                   Barking & Dagenham  \
# 0  34    NaN
# 35    NaN
# 37    NaN
# 39    NaN
# 40    ...
#
#                                               Barnet  \
# 0  339   NaN
# 340   NaN
# 341   NaN
# 342   NaN
# 343   ...
#
#                                               Bexley  \
# 0  642   NaN
# 643   NaN
# 644   NaN
# 645   NaN
# 646   ...
#
#                                                Brent  \
# 0  944    NaN
# 946    NaN
# 947    NaN
# 948    NaN
# 94...
#
#                                              Bromley  \
# 0  1248   NaN
# 1249   NaN
# 1250   NaN
# 1251   NaN
# 12...
#
#                                               Camden  \
# 0  1549   NaN
# 1550   NaN
# 1551   NaN
# 1554   NaN
# 15...
#
#                                       City of London  \
# 0  1851   NaN
# 1855   NaN
# 1856   NaN
# 1857   NaN
# 18...
#
#                                              Croydon  \
# 0  2157   NaN
# 2158   NaN
# 2159   NaN
# 2160   NaN
# 21...
#
#                                               Ealing  \
# 0  2460   NaN
# 2461   NaN
# 2462   NaN
# 2463   NaN
# 24...
#
#                                              Enfield  ...  \
# 0  2763   NaN
# 2764   NaN
# 2765   NaN
# 2766   NaN
# 27...  ...
#
#                                               Merton  \
# 0  7005   NaN
# 7006   NaN
# 7007   NaN
# 7008   NaN
# 70...
#
#                                               Newham  \
# 0  7308   NaN
# 7309   NaN
# 7310   NaN
# 7311   NaN
# 73...
#
#                                            Redbridge  \
# 0  7611   NaN
# 7612   NaN
# 7613   NaN
# 7614   NaN
# 76...
#
#                                 Richmond upon Thames  \
# 0  7912   NaN
# 7914   NaN
# 7915   NaN
# 7917   NaN
# 79...
#
#                                            Southwark  \
# 0  8213   NaN
# 8216   NaN
# 8218   NaN
# 8220   NaN
# 82...
#
#                                               Sutton  \
# 0  8520   NaN
# 8521   NaN
# 8522   NaN
# 8523   NaN
# 85...
#
#                                        Tower Hamlets  \
# 0  8823   NaN
# 8824   NaN
# 8825   NaN
# 8826   NaN
# 88...
#
#                                       Waltham Forest  \
# 0  9126   NaN
# 9127   NaN
# 9128   NaN
# 9129   NaN
# 91...
#
#                                           Wandsworth  \
# 0  9429   NaN
# 9430   NaN
# 9431   NaN
# 9433   NaN
# 94...
#
#                                          Westminster
# 0  9732   NaN
# 9733   NaN
# 9734   NaN
# 9736   NaN
# 97...
#
# [1 rows x 33 columns]

# %%
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index                                                  0
# 0  Barking & Dagenham  34    NaN
# 35    NaN
# 37    NaN
# 39    NaN
# 40    ...
# 1              Barnet  339   NaN
# 340   NaN
# 341   NaN
# 342   NaN
# 343   ...
# 2              Bexley  642   NaN
# 643   NaN
# 644   NaN
# 645   NaN
# 646   ...
# 3               Brent  944    NaN
# 946    NaN
# 947    NaN
# 948    NaN
# 94...
# 4             Bromley  1248   NaN
# 1249   NaN
# 1250   NaN
# 1251   NaN
# 12...

# %%
df_ratios.rename(columns={'index':'Borough', 0:'2018'}, inplace=True)
df_ratios.head()
# Out:
#               Borough                                               2018
# 0  Barking & Dagenham  34    NaN
# 35    NaN
# 37    NaN
# 39    NaN
# 40    ...
# 1              Barnet  339   NaN
# 340   NaN
# 341   NaN
# 342   NaN
# 343   ...
# 2              Bexley  642   NaN
# 643   NaN
# 644   NaN
# 645   NaN
# 646   ...
# 3               Brent  944    NaN
# 946    NaN
# 947    NaN
# 948    NaN
# 94...
# 4             Bromley  1248   NaN
# 1249   NaN
# 1250   NaN
# 1251   NaN
# 12...

# %%
top15 = df_ratios.sort_values(by='2018',ascending=False).head(15)
print(top15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-177-4681373517c5> in <module>
# ----> 1 top15 = df_ratios.sort_values(by='2018',ascending=False).head(15)
#       2 print(top15)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4931
#    4932             indexer = nargsort(
# -> 4933                 k, kind=kind, ascending=ascending, na_position=na_position
#    4934             )
#    4935
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position)
#     272         non_nans = non_nans[::-1]
#     273         non_nan_idx = non_nan_idx[::-1]
# --> 274     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     275     if not ascending:
#     276         indexer = indexer[::-1]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     519
#     520         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 521             raise ValueError("Can only compare identically-labeled Series objects")
#     522
#     523         lvalues = extract_array(self, extract_numpy=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
